# %% [markdown]
# <a href="https://colab.research.google.com/github/nhatboi154/AI/blob/main/bai2AI1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import os
from PIL import Image

# %%
train_data ='drive/MyDrive/baitapvenhaAI2/hinh/training'
test_data='drive/MyDrive/baitapvenhaAI2/hinh/test'
validation_data='drive/MyDrive/baitapvenhaAI2/hinh/validation'

# %%
listdata_train=[]
listdata_test=[]
listdata_validation=[]
dict={'bao':[0],'ngoc':[1],'nhat':[2]}

# %%
def Getdata(dirdata,lstdata):
#doc hinh anh trong tap du lieu
  for whatever in os.listdir(dirdata):
      whatever_path = os.path.join(dirdata,whatever)
      lst_filename_path=[]
      for filename in os.listdir(whatever_path):
        filename_path=os.path.join(whatever_path,filename)
        label=filename_path.split('/')[5]
        img = np.array(Image.open(filename_path))
        lst_filename_path.append((img,dict[label]))
      lstdata.extend(lst_filename_path)
  for i in range(3):
      np.random.shuffle(lstdata)
  return lstdata

# %%
listdata_train=Getdata(train_data,listdata_train)
listdata_test=Getdata(test_data,listdata_test)
listdata_validation=Getdata(validation_data,listdata_validation)

# %%
x_train=np.array([x[0] for _ ,x in enumerate(listdata_train)])
y_train=np.array([y[1] for _ ,y in enumerate(listdata_train)])
y_train.shape
# Out:
# (90, 1)

# %%
x_test=np.array([x[0] for _ ,x in enumerate(listdata_test)])
y_test=np.array([y[1] for _ ,y in enumerate(listdata_test)])

# %%
x_validation=np.array([x[0] for _ ,x in enumerate(listdata_validation)])
y_validation=np.array([y[1] for _ ,y in enumerate(listdata_validation)])
x_validation.shape
# Out:
# (4, 256, 256, 3)

# %%
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense,Activation,Dropout
from tensorflow.keras.optimizers import RMSprop
from keras.callbacks import EarlyStopping
from keras.backend import categorical_crossentropy

# %%
yname=y_train.flatten()

# %%
class_names=['bao','ngoc','nhat']
x_pre=x_test
y_pre=y_test
y_pre
# Out:
# array([[0],
#        [1],
#        [2],
#        [1],
#        [1],
#        [2],
#        [1],
#        [0],
#        [2],
#        [1],
#        [0],
#        [0],
#        [0],
#        [0],
#        [2],
#        [0],
#        [2],
#        [2],
#        [2],
#        [0],
#        [0],
#        [1],
#        [1],
#        [1],
#        [0],
#        [0],
#        [2],
#        [2],
#        [1],
#        [1],
#        [1],
#        [2],
#        [1],
#        [2],
#        [1],
#        [1],
#        [2],
#        [2],
#        [1],
#        [0],
#        [1],
#        [2],
#        [1],
#        [0],
#        [1],
#        [2],
#        [0],
#        [2],
#        [0],
#        [0],
#        [2],
#        [2],
#        [0],
#        [1],
#        [0],
#        [0],
#        [2]])

# %%
plt.figure(figsize=(10, 10))
for i in range(25):
    plt.subplot(5, 5, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(x_train[i], cmap='binary')
    plt.xlabel(class_names[yname[i]])
plt.show()

# %%
from keras.utils import np_utils
x_train=x_train.reshape(90,196608)
x_test=x_test.reshape(57,196608)
x_validation=x_validation.reshape(4,196608)
x_train=x_train.astype('float32')
x_test=x_test.astype('float32')
x_validation=x_validation.astype('float32')
x_train/=255
x_test/=255
x_validation/=255
y_train=np_utils.to_categorical(y_train,3)
y_test= np_utils.to_categorical(y_test,3)
y_validation= np_utils.to_categorical(y_validation,3)

# %%
model=Sequential()
model.add(Dense(1000,activation='relu',input_shape=(196608,)))
model.add(Dense(1000,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(3,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1000)              196609000
#
#  dense_1 (Dense)             (None, 1000)              1001000
#
#  dropout (Dropout)           (None, 1000)              0
#
#  dense_2 (Dense)             (None, 3)                 3003
#
# =================================================================
# Total params: 197,613,003
# Trainable params: 197,613,003
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy
# Epoch 40/200
# 1/1 [==============================] - 0s 137ms/step - loss: 11.3123 - accuracy: 0.3000 - val_loss: 10.5641 - val_accuracy: 0.5000
# Epoch 41/200
# 1/1 [==============================] - 0s 138ms/step - loss: 7.3312 - accuracy: 0.5667 - val_loss: 3.5349 - val_accuracy: 0.7500
# Epoch 42/200
# 1/1 [==============================] - 0s 136ms/step - loss: 4.8328 - accuracy: 0.5667 - val_loss: 5.3633 - val_accuracy: 0.2500
# Epoch 43/200
# 1/1 [==============================] - 0s 140ms/step - loss: 5.6206 - accuracy: 0.3889 - val_loss: 2.9910 - val_accuracy: 0.2500
# Epoch 44/200
# 1/1 [==============================] - 0s 145ms/step - loss: 3.8225 - accuracy: 0.3889 - val_loss: 2.7213 - val_accuracy: 0.5000
# Epoch 45/200
# 1/1 [==============================] - 0s 138ms/step - loss: 1.8957 - accuracy: 0.6222 - val_loss: 1.0137 - val_accuracy: 0.7500
# Epoch 46/200
# 1/1 [==============================] - 0s 137ms/step - loss: 0.6845 - accuracy: 0.6444 - val_loss: 0.6551 - val_accuracy: 0.5000
# Epoch 47/200
# 1/1 [==============================] - 0s 140ms/step - loss: 0.5898 - accuracy: 0.7778 - val_loss: 0.6106 - val_accuracy: 0.5000
# Epoch 48/200
# 1/1 [==============================] - 0s 148ms/step - loss: 0.5720 - accuracy: 0.7889 - val_loss: 0.6132 - val_accuracy: 0.5000
# Epoch 49/200
# 1/1 [==============================] - 0s 136ms/step - loss: 0.5667 - accuracy: 0.8222 - val_loss: 0.5584 - val_accuracy: 0.7500
# Epoch 50/200
# 1/1 [==============================] - 0s 135ms/step - loss: 0.5351 - accuracy: 0.7444 - val_loss: 0.8423 - val_accuracy: 0.5000
# Epoch 51/200
# 1/1 [==============================] - 0s 137ms/step - loss: 0.6113 - accuracy: 0.7778 - val_loss: 1.3643 - val_accuracy: 0.5000
# Epoch 52/200
# 1/1 [==============================] - 0s 138ms/step - loss: 0.9186 - accuracy: 0.6889 - val_loss: 1.3652 - val_accuracy: 0.7500
# Epoch 53/200
# 1/1 [==============================] - 0s 137ms/step - loss: 1.0194 - accuracy: 0.7444 - val_loss: 0.8200 - val_accuracy: 0.2500
# Epoch 54/200
# 1/1 [==============================] - 0s 141ms/step - loss: 0.7087 - accuracy: 0.7444 - val_loss: 0.7388 - val_accuracy: 0.5000
# Epoch 55/200
# 1/1 [==============================] - 0s 136ms/step - loss: 0.6148 - accuracy: 0.7778 - val_loss: 0.8520 - val_accuracy: 0.5000
# Epoch 56/200
# 1/1 [==============================] - 0s 138ms/step - loss: 0.5466 - accuracy: 0.7778 - val_loss: 0.8212 - val_accuracy: 0.5000
# Epoch 57/200
# 1/1 [==============================] - 0s 137ms/step - loss: 0.5873 - accuracy: 0.7667 - val_loss: 0.7391 - val_accuracy: 0.5000
# Epoch 58/200
# 1/1 [==============================] - 0s 139ms/step - loss: 0.5537 - accuracy: 0.7778 - val_loss: 0.7386 - val_accuracy: 0.5000
# Epoch 59/200
# 1/1 [==============================] - 0s 142ms/step - loss: 0.5660 - accuracy: 0.7778 - val_loss: 0.7550 - val_accuracy: 0.5000
# Epoch 60/200
# 1/1 [==============================] - 0s 137ms/step - loss: 0.6311 - accuracy: 0.7667 - val_loss: 0.6615 - val_accuracy: 0.5000
# Epoch 61/200
# 1/1 [==============================] - 0s 139ms/step - loss: 0.5634 - accuracy: 0.8111 - val_loss: 0.7422 - val_accuracy: 0.5000
# Epoch 62/200
# 1/1 [==============================] - 0s 140ms/step - loss: 0.5573 - accuracy: 0.7667 - val_loss: 0.6452 - val_accuracy: 0.5000
# Epoch 63/200
# 1/1 [==============================] - 0s 154ms/step - loss: 0.5710 - accuracy: 0.8222 - val_loss: 0.7216 - val_accuracy: 0.5000
# Epoch 64/200
# 1/1 [==============================] - 0s 138ms/step - loss: 0.5192 - accuracy: 0.7667 - val_loss: 0.6438 - val_accuracy: 0.5000
# Epoch 65/200
# 1/1 [==============================] - 0s 133ms/step - loss: 0.5318 - accuracy: 0.7889 - val_loss: 0.6530 - val_accuracy: 0.5000
# Epoch 66/200
# 1/1 [==============================] - 0s 141ms/step - loss: 0.5170 - accuracy: 0.7667 - val_loss: 0.6520 - val_accuracy: 0.5000
# Epoch 67/200
# 1/1 [==============================] - 0s 152ms/step - loss: 0.5609 - accuracy: 0.7889 - val_loss: 0.6622 - val_accuracy: 0.7500
# Epoch 68/200
# 1/1 [==============================] - 0s 141ms/step - loss: 0.5829 - accuracy: 0.8444 - val_loss: 0.6662 - val_accuracy: 0.7500
# Epoch 69/200
# 1/1 [==============================] - 0s 138ms/step - loss: 0.5873 - accuracy: 0.7889 - val_loss: 0.7322 - val_accuracy: 0.7500
# Epoch 70/200
# 1/1 [==============================] - 0s 144ms/step - loss: 0.6967 - accuracy: 0.7556 - val_loss: 0.6644 - val_accuracy: 0.5000
# Epoch 71/200
# 1/1 [==============================] - 0s 137ms/step - loss: 0.6349 - accuracy: 0.7222 - val_loss: 1.6627 - val_accuracy: 0.7500
# Epoch 72/200
# 1/1 [==============================] - 0s 147ms/step - loss: 1.3249 - accuracy: 0.6333 - val_loss: 0.7440 - val_accuracy: 0.7500
# Epoch 73/200
# 1/1 [==============================] - 0s 140ms/step - loss: 0.7919 - accuracy: 0.6667 - val_loss: 0.7512 - val_accuracy: 0.5000
# Epoch 74/200
# 1/1 [==============================] - 0s 139ms/step - loss: 0.6555 - accuracy: 0.7444 - val_loss: 0.6060 - val_accuracy: 0.5000
# Epoch 75/200
# 1/1 [==============================] - 0s 147ms/step - loss: 0.5963 - accuracy: 0.7333 - val_loss: 0.5775 - val_accuracy: 0.5000
# Epoch 76/200
# 1/1 [==============================] - 0s 146ms/step - loss: 0.5338 - accuracy: 0.8333 - val_loss: 0.7199 - val_accuracy: 0.7500
# Epoch 77/200
# 1/1 [==============================] - 0s 141ms/step - loss: 0.7647 - accuracy: 0.6333 - val_loss: 0.8136 - val_accuracy: 0.5000
# Epoch 78/200
# 1/1 [==============================] - 0s 141ms/step - loss: 0.7229 - accuracy: 0.6556 - val_loss: 0.8100 - val_accuracy: 0.5000
# Epoch 79/200
# 1/1 [==============================] - 0s 136ms/step - loss: 0.7304 - accuracy: 0.6444 - val_loss: 0.8063 - val_accuracy: 0.5000

# %%
Score=model.evaluate(x_test,y_test,verbose=0)
print('Test loss',Score[0])
print('Test accuary', Score[1])
# Out:
# Test loss 1.1513923406600952
# Test accuary 0.5789473652839661

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy and val_accuracy')
plt.xlabel('epochs')
plt.legend(['train','test'])
plt.show()

# %%
plt.figure(figsize=(20, 20))
for i in range(40):
    plt.subplot(10, 4, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(x_pre[i], cmap='binary')
    plt.title("Model dự đoán là: " + str(class_names[np.argmax(model.predict(x_pre[i].reshape((-1,196608))))]))
plt.show()
